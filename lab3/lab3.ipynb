# %%
import numpy as np
from scipy import linalg, sparse
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
from bokeh.plotting import figure, output_file, show
#from bokeh.io import output_file, show
a = 'is'
b = 'nice'
my_list = ['my', 'list', a, b,'my']
array = np.array([[1,2,3],[4,5,6]])
array2 = np.array([[1,2,3],[4,5,6]])
#Variables and Data Types.

#1. index - zwraca index elementu
my_list.index(a)

#2 count - zwraca liczbę występowań podanej w parametrze frazy
my_list.count('my')

#3 append - dodaje element z parametru do listy
my_list.append('!')

#4 remove - usuwa element z listy po nazwie
my_list.remove('!')

#5 del - usuwa elementy z listy od (włącznie) do (rozłącznie)
del(my_list[3:4])

#numpy

#1 shape - Zwraca ilość kolumn i rzędów tablicy
array.shape

#2  len - zwraca liczbę elementów tablicy
len(array)

#3 ndim - zwraca ilu wymiarowa jest to tablica
array.ndim

#4 dtype - zwraca jakiego rodzaju jest to tablica
array.dtype

#5 astype - zmienia typ tablicy i jej elementów na podany w parametrze.
array.astype(str)

#SciPy

#1 asmatrix - tworzy z tablicy macierz
M=np.asmatrix(array2)

#2 T - dokonuje trasnpozycji macierzy
M.T

#3 I - wyznacza macierz odwrotną
M.I

#4 add - dodaje dwie macierze
N=np.asmatrix(array2)
np.add(M,N)

#5 subtract - odejmuje jedną macierz od drugiej

np.subtract(M,N)

#pandas

data = {'Country': ['Belgium', 'India', 'Brazil'],'Capital': ['Brussels', 'New Delhi', 'Brasília'],'Population': [11190846, 1303171035, 207847528]}

df = pd.DataFrame(data,columns=['Country', 'Capital', 'Population'])

#1 df[x:y] wybranie podzbioru

df[1:]

#2 shape - zwraca liczbe kolumn i rzędów
df.shape

#3 columns - zwraca informacje na temat kolumn DataFrame'u
df.columns

#4 mean - zwraca informacje o typie danych i wartości
df.mean()

#5 zwaraca madiane kolumn z liczbami
df.median()

#sklearn
#1 LinearRegression - przekształcenie liniowe
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)

#2 predict - oszacowuje wartość przewidywaną zmiennej 
reg.predict(np.array([[3, 5]]))

#3 Imputer - pozwala na wykrycie pustych rekordów i ich podmiane na wartościowe bazując na podanej strategii w tym przypadku most_frequent
from sklearn.impute import SimpleImputer
data2 = {'Country': ['Belgium', 'India', 'Brazil','Brazil',np.nan],'Capital': ['Brussels', 'New Delhi', 'Brasília','Brasília',np.nan],'Population': [11190846, 1303171035, 207847528,207847528,np.nan]}
df2 = pd.DataFrame(data2,columns=['Country', 'Capital', 'Population'])
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp.fit_transform(df2)

#4 PolynomialFeatures - tworzenie funkcjiwielomianowych
from sklearn.preprocessing import PolynomialFeatures
X = np.arange(6).reshape(3, 2)
poly = PolynomialFeatures(2)
poly.fit_transform(X)

#5 Gaussian NB - Naiwny klasyfikator bayesowski
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
#print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))

#Matplotlib

#x = [1,2,3,4]
#y = [10,20,25,30]
#fig = plt.figure()
#ax = fig.add_subplot(111)

#1. ustawianie koloru linii
#ax.plot(x, y, color='lightblue')

#2. ustawianie grubości linii
#ax.plot(x, y, linewidth=3)

#3 ustawienie markerów
#fig, ax = plt.subplots()
#ax.scatter(x,y,marker=".")
#ax.plot(x,y,marker="o")

#4 ustawienie typu linii jako przerywanej
#plt.plot(x,y,ls='dashed') 

#5 legenda
#ax.set(title='An Example Axes', ylabel='Y-Axis', xlabel='X-Axis')

#seaborn
crash_df=sns.load_dataset('car_crashes')
crash_df

#1 distplot - Rozkład prawdopodobieństwa
#sns.distplot(crash_df['not_distracted'])

#2 Stworzenie wykresu z 2 kolumn
#sns.jointplot(x='speeding',y='alcohol',data=crash_df, kind='hex')

#3 wykres zależności
#sns.kdeplot(crash_df['alcohol'])

#4 całościowy wykres relacyjny
#sns.pairplot(crash_df)

#5 ustawianie wielkości wykresu
#sns.set_style('white')
#plt.figure(figsize=(8,4))
#sns.kdeplot(crash_df['alcohol'])

#bokeh

from bokeh.plotting import figure
p1 = figure(plot_width=300, tools='pan,box_zoom')
p2 = figure(plot_width=300, plot_height=300,
x_range=(0, 8), y_range=(0, 8))
p3 = figure() 
#1 ustawianie markerów
p1.circle(np.array([1,2,3]), np.array([3,2,1]),fill_color='white')
p2.square(np.array([1.5,3.5,5.5]), [1,4,3],color='blue', size=1)

#2 Glify liniowe
p1.line([1,2,3,4], [3,4,5,6], line_width=2)
p2.multi_line(pd.DataFrame([[1,2,3],[5,6,7]]),
pd.DataFrame([[3,4,5],[3,2,1]]),
color="blue")
#3 Glify selektywne i nieselektywne
p = figure(tools='box_select')
p.circle('mpg', 'cyl', source=cds_df,
selection_color='red',
nonselection_alpha=0.1)
#4 glify interaktywne
from bokeh.models import HoverTool
hover = HoverTool(tooltips=None, mode='vline')
p3.add_tools(hover)

#5 output_file - ustawianie typu pliku gdzie zostanie zapisany wykres
output_file("lines2.html")
